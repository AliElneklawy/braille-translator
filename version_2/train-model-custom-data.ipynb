# %%
import numpy as np
import os
import tensorflow as tf
import shutil
import pickle
import gzip
import json
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications.densenet import DenseNet201
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from tensorflow.keras.regularizers import l2
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, precision_score, recall_score, classification_report
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.preprocessing import image
# Out:
# 2024-03-16 22:05:13.993237: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-16 22:05:13.993348: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-16 22:05:14.161173: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# **Preprocessing**

# %%
data, labels, training_data = [], [], []
data_dir = '/kaggle/input/braille-all/augm_data/augm_data'

for char_dir in os.listdir(data_dir):
    char_path = os.path.join(data_dir, char_dir)
    for im in os.listdir(char_path):
        img = image.load_img(os.path.join(char_path, im), target_size=(224, 224))
        x = image.img_to_array(img)
        x = preprocess_input(x)
        x /= 255.0
        training_data.append([x, char_dir])
        
np.random.shuffle(training_data)

# %%
for im, label in training_data:
    data.append(im)
    labels.append(label)
    
X = np.array(data)
y = np.array(labels)

# %%
len(training_data), len(X), len(y)
# Out:
# (6519, 6519, 6519)

# %%
with gzip.open('preprocessed_data.pkl.gz', 'wb') as f:
   pickle.dump({'data': X, 'labels': y}, f)

# %%
#with gzip.open('/kaggle/working/preprocessed_data.pkl.gz', 'rb') as f:
#    loaded_data = pickle.load(f)
    
#len(loaded_data['data']), len(loaded_data['labels'])
# Out:
# (6519, 6519)

# %%
le = LabelEncoder()
y = le.fit_transform(y)
y = to_categorical(y, num_classes=64)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    stratify=y,
                                                    random_state=42)

# %%
checkpoint_cb = ModelCheckpoint('checkpoints.weights.h5', 
                                save_best_only=True,
                                save_weights_only=True, 
                                verbose=1)

reduce_lr_cb = ReduceLROnPlateau(patience=10, verbose=1)

early_stopping_cb = EarlyStopping(patience=20, 
                                  restore_best_weights=True,
                                  start_from_epoch=20,
                                  verbose=1)

# %%
base_model = DenseNet201(weights='imagenet',
                         include_top=False,
                         input_shape=(224, 224, 3))

for layer in base_model.layers:
    layer.trainable = False

for layer in base_model.layers[-40:]:
    layer.trainable = True
    
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu', kernel_regularizer=l2(0.0015))(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
x = Dropout(0.3)(x)
output = Dense(64, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(),
              loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
history = model.fit(x_train, y_train, 
                    epochs=1000, 
                    validation_split=0.2, 
                    callbacks=[checkpoint_cb, reduce_lr_cb, early_stopping_cb])
# Out:
# Epoch 1/1000
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710627016.338333     374 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1710627016.461417     374 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.0276 - loss: 4.6929
# W0000 00:00:1710627071.448661     374 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1710627090.394907     374 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# Epoch 1: val_loss improved from inf to 3.99745, saving model to checkpoints.weights.h5
# W0000 00:00:1710627121.840010     375 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 180s 820ms/step - accuracy: 0.0276 - loss: 4.6910 - val_accuracy: 0.0796 - val_loss: 3.9975 - learning_rate: 0.0010
# Epoch 2/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.0920 - loss: 3.6807
# Epoch 2: val_loss improved from 3.99745 to 2.83067, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.0923 - loss: 3.6783 - val_accuracy: 0.1822 - val_loss: 2.8307 - learning_rate: 0.0010
# Epoch 3/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.2791 - loss: 2.5274
# Epoch 3: val_loss improved from 2.83067 to 1.78139, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.2794 - loss: 2.5261 - val_accuracy: 0.4899 - val_loss: 1.7814 - learning_rate: 0.0010
# Epoch 4/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.4138 - loss: 1.8767
# Epoch 4: val_loss improved from 1.78139 to 1.12195, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.4141 - loss: 1.8757 - val_accuracy: 0.6951 - val_loss: 1.1219 - learning_rate: 0.0010
# Epoch 5/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5665 - loss: 1.4107
# Epoch 5: val_loss improved from 1.12195 to 0.80374, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - accuracy: 0.5667 - loss: 1.4103 - val_accuracy: 0.8102 - val_loss: 0.8037 - learning_rate: 0.0010
# Epoch 6/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6682 - loss: 1.1140
# Epoch 6: val_loss improved from 0.80374 to 0.60396, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.6684 - loss: 1.1133 - val_accuracy: 0.8639 - val_loss: 0.6040 - learning_rate: 0.0010
# Epoch 7/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.7448 - loss: 0.8937
# Epoch 7: val_loss improved from 0.60396 to 0.54477, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.7448 - loss: 0.8936 - val_accuracy: 0.8725 - val_loss: 0.5448 - learning_rate: 0.0010
# Epoch 8/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.7510 - loss: 0.8626
# Epoch 8: val_loss improved from 0.54477 to 0.39032, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 161ms/step - accuracy: 0.7511 - loss: 0.8621 - val_accuracy: 0.9204 - val_loss: 0.3903 - learning_rate: 0.0010
# Epoch 9/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8071 - loss: 0.7280
# Epoch 9: val_loss improved from 0.39032 to 0.32698, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 161ms/step - accuracy: 0.8071 - loss: 0.7280 - val_accuracy: 0.9492 - val_loss: 0.3270 - learning_rate: 0.0010
# Epoch 10/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8416 - loss: 0.6146
# Epoch 10: val_loss improved from 0.32698 to 0.25469, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - accuracy: 0.8416 - loss: 0.6146 - val_accuracy: 0.9636 - val_loss: 0.2547 - learning_rate: 0.0010
# Epoch 11/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8501 - loss: 0.5928
# Epoch 11: val_loss did not improve from 0.25469
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - accuracy: 0.8500 - loss: 0.5928 - val_accuracy: 0.9338 - val_loss: 0.3174 - learning_rate: 0.0010
# Epoch 12/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8458 - loss: 0.5998
# Epoch 12: val_loss improved from 0.25469 to 0.22600, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.8458 - loss: 0.5996 - val_accuracy: 0.9732 - val_loss: 0.2260 - learning_rate: 0.0010
# Epoch 13/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8711 - loss: 0.5017
# Epoch 13: val_loss did not improve from 0.22600
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - accuracy: 0.8710 - loss: 0.5019 - val_accuracy: 0.9453 - val_loss: 0.3095 - learning_rate: 0.0010
# Epoch 14/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8672 - loss: 0.5361
# Epoch 14: val_loss did not improve from 0.22600
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.8673 - loss: 0.5359 - val_accuracy: 0.9693 - val_loss: 0.2446 - learning_rate: 0.0010
# Epoch 15/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8877 - loss: 0.4804
# Epoch 15: val_loss did not improve from 0.22600
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.8877 - loss: 0.4805 - val_accuracy: 0.9674 - val_loss: 0.2334 - learning_rate: 0.0010
# Epoch 16/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8762 - loss: 0.4920
# Epoch 16: val_loss improved from 0.22600 to 0.20946, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.8762 - loss: 0.4919 - val_accuracy: 0.9732 - val_loss: 0.2095 - learning_rate: 0.0010
# Epoch 17/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8994 - loss: 0.4386
# Epoch 17: val_loss did not improve from 0.20946
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 40s 153ms/step - accuracy: 0.8994 - loss: 0.4386 - val_accuracy: 0.9262 - val_loss: 0.3615 - learning_rate: 0.0010
# Epoch 18/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8950 - loss: 0.4287
# Epoch 18: val_loss did not improve from 0.20946
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - accuracy: 0.8950 - loss: 0.4289 - val_accuracy: 0.9722 - val_loss: 0.2119 - learning_rate: 0.0010
# Epoch 19/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9079 - loss: 0.4126
# Epoch 19: val_loss improved from 0.20946 to 0.20150, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.9079 - loss: 0.4127 - val_accuracy: 0.9770 - val_loss: 0.2015 - learning_rate: 0.0010
# Epoch 20/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9183 - loss: 0.3968
# Epoch 20: val_loss did not improve from 0.20150
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9182 - loss: 0.3968 - val_accuracy: 0.9732 - val_loss: 0.2098 - learning_rate: 0.0010
# Epoch 21/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9183 - loss: 0.3782
# Epoch 21: val_loss did not improve from 0.20150
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 156ms/step - accuracy: 0.9183 - loss: 0.3784 - val_accuracy: 0.9684 - val_loss: 0.2248 - learning_rate: 0.0010
# Epoch 22/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9168 - loss: 0.3626
# Epoch 22: val_loss improved from 0.20150 to 0.19813, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.9168 - loss: 0.3627 - val_accuracy: 0.9732 - val_loss: 0.1981 - learning_rate: 0.0010
# Epoch 23/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9030 - loss: 0.4195
# Epoch 23: val_loss did not improve from 0.19813
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9031 - loss: 0.4195 - val_accuracy: 0.9492 - val_loss: 0.2905 - learning_rate: 0.0010
# Epoch 24/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9105 - loss: 0.4021
# Epoch 24: val_loss improved from 0.19813 to 0.17960, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.9105 - loss: 0.4020 - val_accuracy: 0.9808 - val_loss: 0.1796 - learning_rate: 0.0010
# Epoch 25/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9209 - loss: 0.3518
# Epoch 25: val_loss did not improve from 0.17960
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9209 - loss: 0.3519 - val_accuracy: 0.9012 - val_loss: 0.4418 - learning_rate: 0.0010
# Epoch 26/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9195 - loss: 0.3616
# Epoch 26: val_loss did not improve from 0.17960
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9195 - loss: 0.3615 - val_accuracy: 0.9684 - val_loss: 0.2207 - learning_rate: 0.0010
# Epoch 27/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9261 - loss: 0.3376
# Epoch 27: val_loss did not improve from 0.17960
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9261 - loss: 0.3376 - val_accuracy: 0.9760 - val_loss: 0.1951 - learning_rate: 0.0010
# Epoch 28/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9072 - loss: 0.3901
# Epoch 28: val_loss did not improve from 0.17960
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9073 - loss: 0.3899 - val_accuracy: 0.9760 - val_loss: 0.1920 - learning_rate: 0.0010
# Epoch 29/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9296 - loss: 0.3433
# Epoch 29: val_loss did not improve from 0.17960
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9295 - loss: 0.3433 - val_accuracy: 0.9559 - val_loss: 0.2523 - learning_rate: 0.0010
# Epoch 30/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9324 - loss: 0.3322
# Epoch 30: val_loss did not improve from 0.17960
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9324 - loss: 0.3321 - val_accuracy: 0.9684 - val_loss: 0.2171 - learning_rate: 0.0010
# Epoch 31/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9354 - loss: 0.3152
# Epoch 31: val_loss improved from 0.17960 to 0.16847, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 22s 164ms/step - accuracy: 0.9354 - loss: 0.3153 - val_accuracy: 0.9837 - val_loss: 0.1685 - learning_rate: 0.0010
# Epoch 32/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9243 - loss: 0.3684
# Epoch 32: val_loss improved from 0.16847 to 0.15878, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - accuracy: 0.9244 - loss: 0.3682 - val_accuracy: 0.9875 - val_loss: 0.1588 - learning_rate: 0.0010
# Epoch 33/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9375 - loss: 0.3138
# Epoch 33: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9374 - loss: 0.3139 - val_accuracy: 0.9732 - val_loss: 0.1874 - learning_rate: 0.0010
# Epoch 34/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9327 - loss: 0.3170
# Epoch 34: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9327 - loss: 0.3169 - val_accuracy: 0.9789 - val_loss: 0.1714 - learning_rate: 0.0010
# Epoch 35/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9438 - loss: 0.2955
# Epoch 35: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9438 - loss: 0.2955 - val_accuracy: 0.9818 - val_loss: 0.1652 - learning_rate: 0.0010
# Epoch 36/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9310 - loss: 0.3205
# Epoch 36: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9310 - loss: 0.3204 - val_accuracy: 0.9799 - val_loss: 0.1719 - learning_rate: 0.0010
# Epoch 37/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9308 - loss: 0.3216
# Epoch 37: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9308 - loss: 0.3215 - val_accuracy: 0.9645 - val_loss: 0.2221 - learning_rate: 0.0010
# Epoch 38/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9434 - loss: 0.2885
# Epoch 38: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9433 - loss: 0.2885 - val_accuracy: 0.9597 - val_loss: 0.2330 - learning_rate: 0.0010
# Epoch 39/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9498 - loss: 0.2741
# Epoch 39: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9498 - loss: 0.2742 - val_accuracy: 0.9722 - val_loss: 0.1912 - learning_rate: 0.0010
# Epoch 40/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9353 - loss: 0.3105
# Epoch 40: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9354 - loss: 0.3105 - val_accuracy: 0.9693 - val_loss: 0.2037 - learning_rate: 0.0010
# Epoch 41/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9374 - loss: 0.3006
# Epoch 41: val_loss did not improve from 0.15878
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9373 - loss: 0.3006 - val_accuracy: 0.9760 - val_loss: 0.1842 - learning_rate: 0.0010
# Epoch 42/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9405 - loss: 0.2848
# Epoch 42: val_loss improved from 0.15878 to 0.15430, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.9405 - loss: 0.2848 - val_accuracy: 0.9837 - val_loss: 0.1543 - learning_rate: 0.0010
# Epoch 43/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9449 - loss: 0.2704
# Epoch 43: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9448 - loss: 0.2706 - val_accuracy: 0.9684 - val_loss: 0.2111 - learning_rate: 0.0010
# Epoch 44/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9503 - loss: 0.2597
# Epoch 44: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9502 - loss: 0.2598 - val_accuracy: 0.9511 - val_loss: 0.2598 - learning_rate: 0.0010
# Epoch 45/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9547 - loss: 0.2539
# Epoch 45: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9546 - loss: 0.2540 - val_accuracy: 0.9808 - val_loss: 0.1591 - learning_rate: 0.0010
# Epoch 46/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9389 - loss: 0.2903
# Epoch 46: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9389 - loss: 0.2903 - val_accuracy: 0.9655 - val_loss: 0.2136 - learning_rate: 0.0010
# Epoch 47/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9363 - loss: 0.3000
# Epoch 47: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9364 - loss: 0.2999 - val_accuracy: 0.9578 - val_loss: 0.2551 - learning_rate: 0.0010
# Epoch 48/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9415 - loss: 0.2730
# Epoch 48: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9415 - loss: 0.2730 - val_accuracy: 0.9827 - val_loss: 0.1588 - learning_rate: 0.0010
# Epoch 49/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9574 - loss: 0.2334
# Epoch 49: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9574 - loss: 0.2335 - val_accuracy: 0.9770 - val_loss: 0.1704 - learning_rate: 0.0010
# Epoch 50/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9538 - loss: 0.2510
# Epoch 50: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9538 - loss: 0.2510 - val_accuracy: 0.9712 - val_loss: 0.1866 - learning_rate: 0.0010
# Epoch 51/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9491 - loss: 0.2468
# Epoch 51: val_loss did not improve from 0.15430
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9491 - loss: 0.2470 - val_accuracy: 0.9703 - val_loss: 0.2247 - learning_rate: 0.0010
# Epoch 52/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9430 - loss: 0.2576
# Epoch 52: val_loss did not improve from 0.15430
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 151ms/step - accuracy: 0.9430 - loss: 0.2575 - val_accuracy: 0.9703 - val_loss: 0.1947 - learning_rate: 0.0010
# Epoch 53/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9578 - loss: 0.2237
# Epoch 53: val_loss improved from 0.15430 to 0.13521, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.9578 - loss: 0.2236 - val_accuracy: 0.9866 - val_loss: 0.1352 - learning_rate: 1.0000e-04
# Epoch 54/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9684 - loss: 0.2064
# Epoch 54: val_loss improved from 0.13521 to 0.12995, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.9684 - loss: 0.2064 - val_accuracy: 0.9904 - val_loss: 0.1299 - learning_rate: 1.0000e-04
# Epoch 55/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9738 - loss: 0.1805
# Epoch 55: val_loss did not improve from 0.12995
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9738 - loss: 0.1806 - val_accuracy: 0.9895 - val_loss: 0.1311 - learning_rate: 1.0000e-04
# Epoch 56/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9661 - loss: 0.2015
# Epoch 56: val_loss improved from 0.12995 to 0.12855, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.9661 - loss: 0.2015 - val_accuracy: 0.9914 - val_loss: 0.1286 - learning_rate: 1.0000e-04
# Epoch 57/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9713 - loss: 0.1873
# Epoch 57: val_loss did not improve from 0.12855
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9713 - loss: 0.1874 - val_accuracy: 0.9875 - val_loss: 0.1292 - learning_rate: 1.0000e-04
# Epoch 58/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9727 - loss: 0.1851
# Epoch 58: val_loss improved from 0.12855 to 0.12793, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.9727 - loss: 0.1850 - val_accuracy: 0.9885 - val_loss: 0.1279 - learning_rate: 1.0000e-04
# Epoch 59/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9751 - loss: 0.1768
# Epoch 59: val_loss did not improve from 0.12793
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9750 - loss: 0.1769 - val_accuracy: 0.9904 - val_loss: 0.1281 - learning_rate: 1.0000e-04
# Epoch 60/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9678 - loss: 0.1895
# Epoch 60: val_loss improved from 0.12793 to 0.12622, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 22s 165ms/step - accuracy: 0.9678 - loss: 0.1896 - val_accuracy: 0.9914 - val_loss: 0.1262 - learning_rate: 1.0000e-04
# Epoch 61/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9683 - loss: 0.1795
# Epoch 61: val_loss improved from 0.12622 to 0.12433, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 22s 166ms/step - accuracy: 0.9684 - loss: 0.1795 - val_accuracy: 0.9933 - val_loss: 0.1243 - learning_rate: 1.0000e-04
# Epoch 62/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9651 - loss: 0.1947
# Epoch 62: val_loss improved from 0.12433 to 0.12428, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.9651 - loss: 0.1947 - val_accuracy: 0.9933 - val_loss: 0.1243 - learning_rate: 1.0000e-04
# Epoch 63/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9733 - loss: 0.1785
# Epoch 63: val_loss improved from 0.12428 to 0.12038, saving model to checkpoints.weights.h5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.9733 - loss: 0.1785 - val_accuracy: 0.9942 - val_loss: 0.1204 - learning_rate: 1.0000e-04
# Epoch 64/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9714 - loss: 0.1848
# Epoch 64: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9714 - loss: 0.1848 - val_accuracy: 0.9923 - val_loss: 0.1214 - learning_rate: 1.0000e-04
# Epoch 65/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9741 - loss: 0.1759
# Epoch 65: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9740 - loss: 0.1760 - val_accuracy: 0.9933 - val_loss: 0.1227 - learning_rate: 1.0000e-04
# Epoch 66/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9645 - loss: 0.1934
# Epoch 66: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - accuracy: 0.9645 - loss: 0.1933 - val_accuracy: 0.9923 - val_loss: 0.1226 - learning_rate: 1.0000e-04
# Epoch 67/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9711 - loss: 0.1905
# Epoch 67: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9711 - loss: 0.1904 - val_accuracy: 0.9875 - val_loss: 0.1326 - learning_rate: 1.0000e-04
# Epoch 68/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.9692 - loss: 0.1857
# Epoch 68: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9692 - loss: 0.1856 - val_accuracy: 0.9904 - val_loss: 0.1240 - learning_rate: 1.0000e-04
# Epoch 69/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9691 - loss: 0.1777
# Epoch 69: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9692 - loss: 0.1777 - val_accuracy: 0.9885 - val_loss: 0.1247 - learning_rate: 1.0000e-04
# Epoch 70/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9751 - loss: 0.1781
# Epoch 70: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9751 - loss: 0.1782 - val_accuracy: 0.9923 - val_loss: 0.1215 - learning_rate: 1.0000e-04
# Epoch 71/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9787 - loss: 0.1705
# Epoch 71: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9787 - loss: 0.1705 - val_accuracy: 0.9914 - val_loss: 0.1208 - learning_rate: 1.0000e-04
# Epoch 72/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9722 - loss: 0.1772
# Epoch 72: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9722 - loss: 0.1772 - val_accuracy: 0.9895 - val_loss: 0.1248 - learning_rate: 1.0000e-04
# Epoch 73/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9713 - loss: 0.1794
# Epoch 73: val_loss did not improve from 0.12038
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9713 - loss: 0.1794 - val_accuracy: 0.9904 - val_loss: 0.1236 - learning_rate: 1.0000e-04
# Epoch 74/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9761 - loss: 0.1699
# Epoch 74: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9761 - loss: 0.1699 - val_accuracy: 0.9914 - val_loss: 0.1219 - learning_rate: 1.0000e-05
# Epoch 75/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9729 - loss: 0.1833
# Epoch 75: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9729 - loss: 0.1833 - val_accuracy: 0.9923 - val_loss: 0.1212 - learning_rate: 1.0000e-05
# Epoch 76/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9742 - loss: 0.1780
# Epoch 76: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9742 - loss: 0.1780 - val_accuracy: 0.9914 - val_loss: 0.1211 - learning_rate: 1.0000e-05
# Epoch 77/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9755 - loss: 0.1707
# Epoch 77: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9755 - loss: 0.1706 - val_accuracy: 0.9923 - val_loss: 0.1212 - learning_rate: 1.0000e-05
# Epoch 78/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9706 - loss: 0.1710
# Epoch 78: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9706 - loss: 0.1710 - val_accuracy: 0.9923 - val_loss: 0.1214 - learning_rate: 1.0000e-05
# Epoch 79/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9778 - loss: 0.1688
# Epoch 79: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9778 - loss: 0.1688 - val_accuracy: 0.9914 - val_loss: 0.1216 - learning_rate: 1.0000e-05
# Epoch 80/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9767 - loss: 0.1695
# Epoch 80: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9767 - loss: 0.1696 - val_accuracy: 0.9923 - val_loss: 0.1211 - learning_rate: 1.0000e-05
# Epoch 81/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9708 - loss: 0.1770
# Epoch 81: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step - accuracy: 0.9709 - loss: 0.1770 - val_accuracy: 0.9923 - val_loss: 0.1211 - learning_rate: 1.0000e-05
# Epoch 82/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9709 - loss: 0.1818
# Epoch 82: val_loss did not improve from 0.12038
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9710 - loss: 0.1817 - val_accuracy: 0.9923 - val_loss: 0.1208 - learning_rate: 1.0000e-05
# Epoch 83/1000
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.9767 - loss: 0.1663
# Epoch 83: val_loss did not improve from 0.12038
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 153ms/step - accuracy: 0.9767 - loss: 0.1663 - val_accuracy: 0.9914 - val_loss: 0.1205 - learning_rate: 1.0000e-05
# Epoch 83: early stopping
# Restoring model weights from the end of the best epoch: 63.

# %% [markdown]
# # Evaluate the model

# %% [markdown]
# ## Learning curves

# %%
# Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.grid()
plt.show()

# Model Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.grid()
plt.show()

# %% [markdown]
# ## Training accuracy, recall and precision

# %%
class_names = [label for label in os.listdir(data_dir)]

# %%
model.evaluate(x_train, y_train)
# Out:
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 51s 315ms/step - accuracy: 0.9998 - loss: 0.0956
# W0000 00:00:1710629220.469961     374 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# [0.10005952417850494, 0.9988494515419006]

# %%
model.evaluate(x_test, y_test)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 34s 843ms/step - accuracy: 0.9895 - loss: 0.1294
# W0000 00:00:1710629147.314548     374 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# [0.12867097556591034, 0.9900306463241577]

# %%
y_pred_probs_train = model.predict(x_train)
y_pred_train = np.argmax(y_pred_probs_train, axis=1)
y_true_train = np.argmax(y_train, axis=1)
# Out:
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 17s 107ms/step

# %%
precision = precision_score(y_true_train, y_pred_train, average='macro')
print('Training precision: %.3f' % precision)
# Out:
# Training precision: 0.999

# %%
recall = recall_score(y_true_train, y_pred_train, average='macro')
print('Training recall: %.3f' % recall)
# Out:
# Training recall: 0.999

# %%
report = classification_report(y_true_train, y_pred_train, target_names=class_names)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       110010       0.99      1.00      0.99        84
#       000001       1.00      1.00      1.00        80
#       000110       1.00      1.00      1.00        84
#       111001       1.00      1.00      1.00        82
#       110111       1.00      1.00      1.00        80
#       001101       1.00      1.00      1.00        84
#       010000       1.00      1.00      1.00        82
#       100000       1.00      1.00      1.00        82
#       111111       1.00      1.00      1.00        80
#       100001       1.00      1.00      1.00        80
#       100111       1.00      1.00      1.00        80
#       101011       1.00      1.00      1.00        80
#       001000       1.00      1.00      1.00        80
#       101100       1.00      1.00      1.00        80
#       100100       1.00      1.00      1.00        80
#       110101       1.00      1.00      1.00        82
#       010101       1.00      0.99      0.99        80
#       011000       1.00      1.00      1.00        80
#       011011       1.00      1.00      1.00        80
#       001100       1.00      1.00      1.00        82
#       110100       1.00      1.00      1.00        88
#       001111       1.00      1.00      1.00        80
#       101111       1.00      0.99      0.99        80
#       000011       0.98      1.00      0.99        80
#       011101       1.00      1.00      1.00        80
#       001001       1.00      1.00      1.00        80
#       000111       1.00      1.00      1.00        80
#       110110       1.00      1.00      1.00        80
#       010001       1.00      1.00      1.00        80
#       001010       1.00      1.00      1.00        80
#       011110       1.00      1.00      1.00        88
#       110001       1.00      0.99      0.99        80
#       000101       1.00      0.99      0.99        89
#       101001       1.00      1.00      1.00        80
#       111110       1.00      1.00      1.00        86
#       101010       1.00      1.00      1.00        80
#       001110       1.00      0.99      0.99        86
#       111000       1.00      1.00      1.00        80
#       110000       1.00      1.00      1.00        86
#       101101       1.00      1.00      1.00        80
#       100011       1.00      1.00      1.00        80
#       000010       1.00      1.00      1.00        82
#       010100       1.00      1.00      1.00        88
#       111011       1.00      1.00      1.00        80
#       101110       1.00      1.00      1.00        80
#       111010       1.00      1.00      1.00        80
#       011111       1.00      1.00      1.00        82
#       011001       1.00      1.00      1.00        80
#       111100       0.98      1.00      0.99        86
#       010010       1.00      0.99      0.99        80
#       011010       1.00      1.00      1.00        83
#       100010       1.00      1.00      1.00        80
#       001011       0.99      1.00      0.99        80
#       100101       1.00      1.00      1.00        80
#       000000       1.00      1.00      1.00        83
#       010011       1.00      1.00      1.00        80
#       100110       1.00      1.00      1.00        80
#       110011       1.00      1.00      1.00        80
#       011100       1.00      1.00      1.00        86
#       000100       1.00      1.00      1.00        80
#       010110       1.00      1.00      1.00        80
#       101000       1.00      1.00      1.00        80
#       010111       1.00      1.00      1.00        80
#       111101       1.00      1.00      1.00        80
#
#     accuracy                           1.00      5215
#    macro avg       1.00      1.00      1.00      5215
# weighted avg       1.00      1.00      1.00      5215

# %% [markdown]
# ## Test accuracy, recall and precision

# %%
y_pred_probs_test = model.predict(x_test)
y_pred_test = np.argmax(y_pred_probs_test, axis=1)
y_true_test = np.argmax(y_test, axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 15s 379ms/step
# W0000 00:00:1710629772.941329     374 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update

# %%
precision = precision_score(y_true_test, y_pred_test, average='macro')
print('Test precision: %.3f' % precision)
# Out:
# Test precision: 0.990

# %%
recall = recall_score(y_true_test, y_pred_test, average='macro')
print('Test precision: %.3f' % recall)
# Out:
# Test precision: 0.990

# %%
report = classification_report(y_true_test, y_pred_test, target_names=class_names)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#       110010       1.00      0.90      0.95        21
#       000001       0.91      1.00      0.95        20
#       000110       0.95      1.00      0.98        21
#       111001       1.00      1.00      1.00        20
#       110111       1.00      1.00      1.00        20
#       001101       1.00      1.00      1.00        21
#       010000       1.00      0.95      0.97        20
#       100000       1.00      1.00      1.00        20
#       111111       0.95      1.00      0.98        20
#       100001       1.00      0.95      0.97        20
#       100111       1.00      1.00      1.00        20
#       101011       1.00      1.00      1.00        20
#       001000       1.00      1.00      1.00        20
#       101100       1.00      1.00      1.00        20
#       100100       0.95      1.00      0.98        20
#       110101       1.00      1.00      1.00        20
#       010101       1.00      0.95      0.97        20
#       011000       1.00      1.00      1.00        20
#       011011       1.00      1.00      1.00        20
#       001100       1.00      1.00      1.00        20
#       110100       1.00      1.00      1.00        22
#       001111       1.00      1.00      1.00        20
#       101111       0.95      1.00      0.98        20
#       000011       1.00      1.00      1.00        20
#       011101       1.00      1.00      1.00        20
#       001001       1.00      1.00      1.00        20
#       000111       1.00      1.00      1.00        20
#       110110       1.00      1.00      1.00        20
#       010001       1.00      1.00      1.00        20
#       001010       1.00      1.00      1.00        20
#       011110       1.00      0.95      0.98        22
#       110001       1.00      1.00      1.00        20
#       000101       1.00      0.96      0.98        23
#       101001       1.00      1.00      1.00        20
#       111110       1.00      0.95      0.98        22
#       101010       0.95      1.00      0.98        20
#       001110       1.00      1.00      1.00        22
#       111000       1.00      1.00      1.00        20
#       110000       0.96      1.00      0.98        22
#       101101       1.00      0.95      0.97        20
#       100011       0.95      1.00      0.98        20
#       000010       1.00      1.00      1.00        20
#       010100       1.00      1.00      1.00        22
#       111011       1.00      1.00      1.00        20
#       101110       1.00      0.95      0.97        20
#       111010       1.00      1.00      1.00        20
#       011111       1.00      1.00      1.00        20
#       011001       0.95      1.00      0.98        20
#       111100       1.00      1.00      1.00        22
#       010010       1.00      1.00      1.00        20
#       011010       1.00      1.00      1.00        21
#       100010       1.00      1.00      1.00        20
#       001011       1.00      0.95      0.97        20
#       100101       0.95      0.95      0.95        20
#       000000       1.00      1.00      1.00        21
#       010011       1.00      1.00      1.00        20
#       100110       1.00      1.00      1.00        20
#       110011       1.00      1.00      1.00        20
#       011100       1.00      1.00      1.00        22
#       000100       1.00      1.00      1.00        20
#       010110       0.95      1.00      0.98        20
#       101000       0.95      0.95      0.95        20
#       010111       1.00      1.00      1.00        20
#       111101       1.00      1.00      1.00        20
#
#     accuracy                           0.99      1304
#    macro avg       0.99      0.99      0.99      1304
# weighted avg       0.99      0.99      0.99      1304

# %% [markdown]
# # Save the model and its metadata

# %%
# h5 format

model.save('custom_data_model.h5')

# %%
# Saving the metadata

metadata = {
    "author": "Ali ELneklawy, Nada Gamal, Nada Tarek",
    "description": "A model trained on our custom data",
    "date": "2024-03-17",
    "tensorflow_version": tf.__version__ # Include the TensorFlow version used to save the model
}

metadata_path = '/kaggle/working/metadata.json'
with open(metadata_path, 'w') as f:
    json.dump(metadata, f)

# %%
metadata_path = "/kaggle/working/metadata.json"

with open(metadata_path, 'r') as f:
    loaded_metadata = json.load(f)

print(loaded_metadata)
# Out:
# {'author': 'Ali ELneklawy, Nada Gamal, Nada Tarek', 'description': 'A model trained on our custom data', 'date': '2024-03-17', 'tensorflow_version': '2.15.0'}

# %%
# tf version used to save the model

print(tf.__version__)
# Out:
# 2.15.0

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# accelerate==0.27.2
# access==1.1.9
# affine==2.4.0
# aiobotocore==2.11.2
# aiofiles==22.1.0
# aiohttp @ file:///home/conda/feedstock_root/build_artifacts/aiohttp_1701099469104/work
# aiohttp-cors==0.7.0
# aioitertools==0.11.0
# aiorwlock==1.3.0
# aiosignal @ file:///home/conda/feedstock_root/build_artifacts/aiosignal_1667935791922/work
# aiosqlite==0.19.0
# albumentations==1.4.0
# alembic==1.13.1
# altair==5.2.0
# annotated-types @ file:///home/conda/feedstock_root/build_artifacts/annotated-types_1696634205638/work
# annoy==1.17.3
# anyio @ file:///home/conda/feedstock_root/build_artifacts/anyio_1702909220329/work
# apache-beam==2.46.0
# aplus==0.11.0
# appdirs==1.4.4
# archspec @ file:///home/conda/feedstock_root/build_artifacts/archspec_1699370045702/work
# argon2-cffi @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi_1692818318753/work
# argon2-cffi-bindings @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi-bindings_1695386546427/work
# array-record==0.5.0
# arrow @ file:///home/conda/feedstock_root/build_artifacts/arrow_1696128962909/work
# arviz==0.17.0
# astroid==3.0.3
# astropy==6.0.0
# astropy-iers-data==0.2024.2.19.0.28.47
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1698341106958/work
# astunparse==1.6.3
# async-lru==2.0.4
# async-timeout @ file:///home/conda/feedstock_root/build_artifacts/async-timeout_1691763562544/work
# attrs @ file:///home/conda/feedstock_root/build_artifacts/attrs_1704011227531/work
# audioread==3.0.1
# autopep8==2.0.4
# Babel==2.14.0
# backoff==2.2.1
# bayesian-optimization==1.4.3
# bayespy==0.5.28
# beatrix_jupyterlab @ file:///home/kbuilder/miniconda3/conda-bld/dlenv-tf-2-15-gpu_1704941576253/work/packages/beatrix_jupyterlab-2023.128.151533.tar.gz#sha256=8c6941d08ce18f5b9ea7719574d611c18163074ff8254e0734342014eb064a48
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1680888073205/work
# bidict==0.23.1
# biopython==1.83
# blake3==0.2.1
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1696630167146/work
# blessed==1.20.0
# blinker==1.7.0
# blis @ file:///home/conda/feedstock_root/build_artifacts/cython-blis_1696148805003/work
# blosc2==2.5.1
# bokeh @ file:///home/conda/feedstock_root/build_artifacts/bokeh_1706215790147/work
# boltons @ file:///home/conda/feedstock_root/build_artifacts/boltons_1703154663129/work
# Boruta==0.3
# boto3==1.26.100
# botocore==1.34.34
# bq_helper==0.4.1
# bqplot==0.12.43
# branca==0.7.1
# brewer2mpl==1.4.1
# Brotli @ file:///home/conda/feedstock_root/build_artifacts/brotli-split_1687884021435/work
# brotlipy==0.7.0
# cached-property @ file:///home/conda/feedstock_root/build_artifacts/cached_property_1615209429212/work
# cachetools==4.2.4
# Cartopy @ file:///home/conda/feedstock_root/build_artifacts/cartopy_1698172724393/work
# catalogue @ file:///home/conda/feedstock_root/build_artifacts/catalogue_1695626339626/work
# catalyst @ git+https://github.com/Philmod/catalyst.git@9420384a98c4b9d3b17b959e66f845b98457b545
# catboost==1.2.2
# category-encoders==2.6.3
# certifi @ file:///home/conda/feedstock_root/build_artifacts/certifi_1707022139797/work/certifi
# cesium==0.12.1
# cffi @ file:///home/conda/feedstock_root/build_artifacts/cffi_1696001684923/work
# charset-normalizer @ file:///home/conda/feedstock_root/build_artifacts/charset-normalizer_1698833585322/work
# chex==0.1.85
# cleverhans==4.0.0
# click @ file:///home/conda/feedstock_root/build_artifacts/click_1692311806742/work
# click-plugins==1.1.1
# cligj==0.7.2
# cloud-tpu-client==0.10
# cloud-tpu-profiler==2.4.0
# cloudpathlib @ file:///home/conda/feedstock_root/build_artifacts/cloudpathlib-meta_1697837790453/work
# cloudpickle==2.2.1
# cmdstanpy==1.2.1
# cmudict==1.0.18
# colorama @ file:///home/conda/feedstock_root/build_artifacts/colorama_1666700638685/work
# colorcet==3.0.1
# colorful==0.5.6
# colorlog==6.8.2
# colorlover==0.3.0
# comm @ file:///home/conda/feedstock_root/build_artifacts/comm_1704278392174/work
# conda @ file:///home/conda/feedstock_root/build_artifacts/conda_1694556045812/work
# conda-libmamba-solver @ file:///home/conda/feedstock_root/build_artifacts/conda-libmamba-solver_1690880668143/work/src
# conda-package-handling @ file:///home/conda/feedstock_root/build_artifacts/conda-package-handling_1691048088238/work
# conda_package_streaming @ file:///home/conda/feedstock_root/build_artifacts/conda-package-streaming_1691009212940/work
# confection @ file:///home/conda/feedstock_root/build_artifacts/confection_1701179074719/work
# contextily==1.5.0
# contourpy @ file:///home/conda/feedstock_root/build_artifacts/contourpy_1699041363598/work
# convertdate==2.4.0
# crcmod==1.7
# cryptography @ file:///home/conda/feedstock_root/build_artifacts/cryptography-split_1701563205069/work
# cuda-python @ file:///opt/conda/conda-bld/cuda-python_1696638333144/work
# cudf @ file:///opt/conda/conda-bld/work/python/cudf
# cufflinks==0.17.3
# cuml @ file:///opt/conda/conda-bld/work/python
# cupy @ file:///home/conda/feedstock_root/build_artifacts/cupy-split_1707093121318/work
# CVXcanon==0.1.2
# cycler @ file:///home/conda/feedstock_root/build_artifacts/cycler_1696677705766/work
# cymem @ file:///home/conda/feedstock_root/build_artifacts/cymem_1695443485440/work
# cysignals==1.11.4
# Cython==3.0.8
# cytoolz @ file:///home/conda/feedstock_root/build_artifacts/cytoolz_1706897049115/work
# daal==2024.1.0
# daal4py==2024.1.0
# dacite==1.8.1
# dask==2024.2.0
# dask-cuda @ file:///opt/conda/conda-bld/work
# dask-cudf @ file:///opt/conda/conda-bld/work/python/dask_cudf
# dataclasses-json==0.6.4
# dataproc_jupyter_plugin==0.1.66
# datasets==2.1.0
# datashader==0.16.0
# datatile==1.0.3
# db-dtypes==1.2.0
# deap==1.4.1
# debugpy @ file:///home/conda/feedstock_root/build_artifacts/debugpy_1695534290310/work
# decorator @ file:///home/conda/feedstock_root/build_artifacts/decorator_1641555617451/work
# deepdiff==6.7.1
# defusedxml @ file:///home/conda/feedstock_root/build_artifacts/defusedxml_1615232257335/work
# Delorean==1.0.0
# Deprecated==1.2.14
# deprecation==2.1.0
# descartes==1.1.0
# dill==0.3.8
# dipy==1.8.0
# distlib==0.3.8
# distributed @ file:///home/conda/feedstock_root/build_artifacts/distributed_1689891044039/work
# distro @ file:///home/conda/feedstock_root/build_artifacts/distro_1704321475663/work
# dm-tree==0.1.8
# docker==7.0.0
# docker-pycreds==0.4.0
# docopt==0.6.2
# docstring-parser==0.15
# docstring-to-markdown==0.15
# docutils==0.20.1
# earthengine-api==0.1.391
# easydict==1.12
# easyocr==1.7.1
# ecos==2.0.13
# eli5==0.13.0
# emoji==2.10.1
# en-core-web-lg @ https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl#sha256=ab70aeb6172cde82508f7739f35ebc9918a3d07debeed637403c8f794ba3d3dc
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl#sha256=86cc141f63942d4b2c5fcee06630fd6f904788d2f0ab005cce45aadb8fb73889
# entrypoints @ file:///home/conda/feedstock_root/build_artifacts/entrypoints_1643888246732/work
# ephem==4.1.5
# esda==2.5.1
# essentia==2.1b6.dev1110
# et-xmlfile==1.1.0
# etils==1.6.0
# exceptiongroup @ file:///home/conda/feedstock_root/build_artifacts/exceptiongroup_1704921103267/work
# executing @ file:///home/conda/feedstock_root/build_artifacts/executing_1698579936712/work
# explainable-ai-sdk==1.3.3
# Farama-Notifications==0.0.4
# fastai==2.7.14
# fastapi==0.108.0
# fastavro==1.9.3
# fastcore==1.5.29
# fastdownload==0.0.7
# fasteners==0.19
# fastjsonschema @ file:///home/conda/feedstock_root/build_artifacts/python-fastjsonschema_1703780968325/work/dist
# fastprogress==1.0.3
# fastrlock @ file:///home/conda/feedstock_root/build_artifacts/fastrlock_1702696298817/work
# fasttext==0.9.2
# fbpca==1.0
# feather-format==0.4.1
# featuretools==1.29.0
# filelock==3.13.1
# fiona==1.9.5
# fitter==1.7.0
# flake8==7.0.0
# flashtext==2.7
# Flask==3.0.2
# flatbuffers==23.5.26
# flax==0.8.1
# folium==0.15.1
# fonttools==4.47.0
# fqdn @ file:///home/conda/feedstock_root/build_artifacts/fqdn_1638810296540/work/dist
# frozendict==2.4.0
# frozenlist @ file:///home/conda/feedstock_root/build_artifacts/frozenlist_1702645481127/work
# fsspec @ file:///home/conda/feedstock_root/build_artifacts/fsspec_1707102468451/work
# funcy==2.0
# fury==0.9.0
# future==1.0.0
# fuzzywuzzy==0.18.0
# gast==0.5.4
# gatspy==0.3
# gcsfs==2023.12.2.post1
# gensim==4.3.2
# geographiclib==2.0
# Geohash==1.0
# geojson==3.1.0
# geopandas==0.14.3
# geoplot==0.5.1
# geopy==2.4.1
# geoviews==1.11.1
# ggplot @ https://github.com/hbasria/ggpy/archive/0.11.5.zip#sha256=7df947ba3fd86d3757686afec264785ad8df38dc50ffb2d2d31064fb355f69b1
# giddy==2.3.5
# gitdb==4.0.11
# GitPython==3.1.41
# google-ai-generativelanguage==0.4.0
# google-api-core==2.11.1
# google-api-python-client==2.118.0
# google-apitools==0.5.31
# google-auth==2.26.1
# google-auth-httplib2==0.1.1
# google-auth-oauthlib==1.2.0
# google-cloud-aiplatform==0.6.0a1
# google-cloud-artifact-registry==1.10.0
# google-cloud-automl==1.0.1
# google-cloud-bigquery==2.34.4
# google-cloud-bigtable==1.7.3
# google-cloud-core==2.4.1
# google-cloud-datastore==2.19.0
# google-cloud-dlp==3.14.0
# google-cloud-jupyter-config==0.0.5
# google-cloud-language==2.13.1
# google-cloud-monitoring==2.18.0
# google-cloud-pubsub==2.19.0
# google-cloud-pubsublite==1.9.0
# google-cloud-recommendations-ai==0.7.1
# google-cloud-resource-manager==1.11.0
# google-cloud-spanner==3.40.1
# google-cloud-storage==1.44.0
# google-cloud-translate==3.12.1
# google-cloud-videointelligence==2.13.1
# google-cloud-vision==2.8.0
# google-crc32c==1.5.0
# google-generativeai==0.3.2
# google-pasta==0.2.0
# google-resumable-media==2.7.0
# googleapis-common-protos==1.62.0
# gplearn==0.4.2
# gpustat==1.0.0
# gpxpy==1.6.2
# graphviz==0.20.1
# greenlet==3.0.3
# grpc-google-iam-v1==0.12.7
# grpcio @ file:///home/conda/feedstock_root/build_artifacts/grpc-split_1677499296072/work
# grpcio-status @ file:///home/conda/feedstock_root/build_artifacts/grpcio-status_1662108958711/work
# gviz-api==1.10.0
# gym==0.26.2
# gym-notices==0.0.8
# gymnasium==0.29.0
# h11==0.14.0
# h2o==3.44.0.3
# h5netcdf==1.3.0
# h5py==3.10.0
# haversine==2.8.1
# hdfs==2.7.3
# hep-ml==0.7.2
# hijri-converter==2.3.1
# hmmlearn==0.3.0
# holidays==0.24
# holoviews==1.18.3
# hpsklearn==0.1.0
# html5lib==1.1
# htmlmin==0.1.12
# httpcore==1.0.4
# httplib2==0.21.0
# httptools==0.6.1
# httpx==0.27.0
# huggingface-hub==0.20.3
# humanize==4.9.0
# hunspell==0.5.5
# husl==4.0.3
# hydra-slayer==0.5.0
# hyperopt==0.2.7
# hypertools==0.8.0
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1701026962277/work
# igraph==0.11.4
# imagecodecs==2024.1.1
# ImageHash==4.3.1
# imageio==2.33.1
# imbalanced-learn==0.12.0
# imgaug==0.4.0
# importlib-metadata==6.11.0
# importlib-resources @ file:///home/conda/feedstock_root/build_artifacts/importlib_resources_1699364556997/work
# inequality==1.0.1
# iniconfig==2.0.0
# ipydatawidgets==4.3.5
# ipykernel @ file:///home/conda/feedstock_root/build_artifacts/ipykernel_1703631723894/work
# ipyleaflet==0.18.2
# ipympl==0.7.0
# ipython @ file:///home/conda/feedstock_root/build_artifacts/ipython_1704718870316/work
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipyvolume==0.6.3
# ipyvue==1.10.1
# ipyvuetify==1.8.10
# ipywebrtc==0.6.0
# ipywidgets==7.7.1
# isoduration @ file:///home/conda/feedstock_root/build_artifacts/isoduration_1638811571363/work/dist
# isort==5.13.2
# isoweek==1.3.3
# itsdangerous==2.1.2
# Janome==0.5.0
# jaraco.classes==3.3.0
# jax==0.4.23
# jax-jumpy==1.0.0
# jaxlib @ file:///tmp/jax/jaxlib-0.4.23.dev20240116-cp310-cp310-manylinux2014_x86_64.whl#sha256=2adde6b0fff8a64af0b461e617ac514b80d8ee4aa52f1b1cf9a9139f427be8ba
# jedi @ file:///home/conda/feedstock_root/build_artifacts/jedi_1696326070614/work
# jeepney==0.8.0
# jieba==0.42.1
# Jinja2 @ file:///home/conda/feedstock_root/build_artifacts/jinja2_1654302431367/work
# jmespath==1.0.1
# joblib @ file:///home/conda/feedstock_root/build_artifacts/joblib_1691577114857/work
# json5==0.9.14
# jsonpatch @ file:///home/conda/feedstock_root/build_artifacts/jsonpatch_1695536281965/work
# jsonpointer @ file:///home/conda/feedstock_root/build_artifacts/jsonpointer_1695397238043/work
# jsonschema @ file:///home/conda/feedstock_root/build_artifacts/jsonschema-meta_1700159890288/work
# jsonschema-specifications @ file:///tmp/tmpkv1z7p57/src
# jupyter-console==6.6.3
# jupyter-events @ file:///home/conda/feedstock_root/build_artifacts/jupyter_events_1699285872613/work
# jupyter-http-over-ws==0.0.8
# jupyter-lsp==1.5.1
# jupyter-server-mathjax==0.2.6
# jupyter-ydoc==0.2.5
# jupyter_client==7.4.9
# jupyter_core @ file:///home/conda/feedstock_root/build_artifacts/jupyter_core_1704727030956/work
# jupyter_server==2.12.5
# jupyter_server_fileid==0.9.1
# jupyter_server_proxy==4.1.0
# jupyter_server_terminals @ file:///home/conda/feedstock_root/build_artifacts/jupyter_server_terminals_1703611053195/work
# jupyter_server_ydoc==0.8.0
# jupyterlab==4.1.2
# jupyterlab-lsp==5.0.3
# jupyterlab-widgets==3.0.9
# jupyterlab_git==0.44.0
# jupyterlab_pygments @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_pygments_1700744013163/work
# jupyterlab_server==2.25.2
# jupytext==1.16.0
# kaggle==1.6.6
# kaggle-environments==1.14.3
# kagglehub==0.1.9
# keras==3.0.5
# keras-cv==0.8.2
# keras-nlp==0.8.1
# keras-tuner==1.4.6
# kernels-mixer==0.0.7
# keyring==24.3.0
# keyrings.google-artifactregistry-auth==1.1.2
# kfp==2.5.0
# kfp-pipeline-spec==0.2.2
# kfp-server-api==2.0.5
# kiwisolver @ file:///home/conda/feedstock_root/build_artifacts/kiwisolver_1695379902431/work
# kmapper==2.0.1
# kmodes==0.12.2
# korean-lunar-calendar==0.3.1
# kornia==0.7.1
# kt-legacy==1.0.5
# kubernetes==26.1.0
# langcodes @ file:///home/conda/feedstock_root/build_artifacts/langcodes_1636741340529/work
# langid==1.1.6
# lazy_loader==0.3
# learntools @ git+https://github.com/Kaggle/learntools@183cdad0530e7c898cd4658a63b579c54e91f056
# leven==1.0.4
# Levenshtein==0.25.0
# libclang==16.0.6
# libmambapy @ file:///home/conda/feedstock_root/build_artifacts/mamba-split_1692866066721/work/libmambapy
# libpysal==4.9.2
# librosa==0.10.1
# lightgbm @ file:///tmp/lightgbm/lightgbm-4.2.0-py3-none-manylinux_2_31_x86_64.whl#sha256=26ed21477c12bb26edc4d6d51336cd43d5a8f7daf55ebbe27b0faf50ce96db23
# lightning-utilities==0.10.1
# lime==0.2.0.1
# line-profiler==4.1.2
# linkify-it-py==2.0.3
# llvmlite==0.41.1
# lml==0.1.0
# locket @ file:///home/conda/feedstock_root/build_artifacts/locket_1650660393415/work
# loguru==0.7.2
# LunarCalendar==0.0.9
# lxml==5.1.0
# lz4 @ file:///home/conda/feedstock_root/build_artifacts/lz4_1704831084136/work
# Mako==1.3.2
# mamba @ file:///home/conda/feedstock_root/build_artifacts/mamba-split_1692866066721/work/mamba
# mapclassify==2.6.1
# marisa-trie==1.1.0
# Markdown==3.5.2
# markdown-it-py @ file:///home/conda/feedstock_root/build_artifacts/markdown-it-py_1686175045316/work
# markovify==0.9.4
# MarkupSafe @ file:///home/conda/feedstock_root/build_artifacts/markupsafe_1695367434228/work
# marshmallow==3.20.2
# matplotlib==3.7.5
# matplotlib-inline @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-inline_1660814786464/work
# matplotlib-venn==0.11.10
# mccabe==0.7.0
# mdit-py-plugins==0.4.0
# mdurl @ file:///home/conda/feedstock_root/build_artifacts/mdurl_1704317613764/work
# memory-profiler==0.61.0
# menuinst @ file:///home/conda/feedstock_root/build_artifacts/menuinst_1702317041727/work
# mercantile==1.2.1
# mgwr==2.2.1
# missingno==0.5.2
# mistune==0.8.4
# mizani==0.11.0
# ml-dtypes==0.2.0
# mlcrate==0.2.0
# mlens==0.2.3
# mlxtend==0.23.1
# mmh3==4.1.0
# mne==1.6.1
# mnist==0.2.2
# mock==5.1.0
# momepy==0.7.0
# more-itertools==10.2.0
# mpld3==0.5.10
# mpmath==1.3.0
# msgpack @ file:///home/conda/feedstock_root/build_artifacts/msgpack-python_1700926504817/work
# msgpack-numpy==0.4.8
# multidict @ file:///home/conda/feedstock_root/build_artifacts/multidict_1696716075096/work
# multimethod==1.10
# multipledispatch==1.0.0
# multiprocess==0.70.16
# munkres==1.1.4
# murmurhash @ file:///home/conda/feedstock_root/build_artifacts/murmurhash_1695449783955/work
# mypy-extensions==1.0.0
# namex==0.0.7
# nb-conda-kernels @ file:///home/conda/feedstock_root/build_artifacts/nb_conda_kernels_1699980974206/work
# nb_conda @ file:///home/conda/feedstock_root/build_artifacts/nb_conda_1704789357480/work
# nbclassic @ file:///home/conda/feedstock_root/build_artifacts/nbclassic_1683202081046/work
# nbclient==0.5.13
# nbconvert==6.4.5
# nbdime==3.2.0
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1690814868471/work
# ndindex==1.8
# nest-asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1697083700168/work
# networkx==3.2.1
# nibabel==5.2.0
# nilearn==0.10.3
# ninja==1.11.1.1
# nltk==3.2.4
# nose==1.3.7
# notebook @ file:///home/conda/feedstock_root/build_artifacts/notebook_1680870634737/work
# notebook_executor @ file:///home/kbuilder/miniconda3/conda-bld/dlenv-tf-2-15-gpu_1704941576253/work/packages/notebook_executor
# notebook_shim @ file:///home/conda/feedstock_root/build_artifacts/notebook-shim_1682360583588/work
# numba==0.58.1
# numexpr==2.9.0
# numpy @ file:///home/conda/feedstock_root/build_artifacts/numpy_1707225380409/work/dist/numpy-1.26.4-cp310-cp310-linux_x86_64.whl#sha256=51131fd8fc130cd168aecaf1bc0ea85f92e8ffebf211772ceb16ac2e7f10d7ca
# nvidia-ml-py==11.495.46
# nvtx @ file:///home/conda/feedstock_root/build_artifacts/nvtx_1708093799817/work
# oauth2client==4.1.3
# oauthlib==3.2.2
# objsize==0.6.1
# odfpy==1.4.1
# olefile==0.47
# onnx==1.15.0
# opencensus==0.11.4
# opencensus-context==0.1.3
# opencv-contrib-python==4.9.0.80
# opencv-python==4.9.0.80
# opencv-python-headless==4.9.0.80
# openpyxl==3.1.2
# openslide-python==1.3.1
# opentelemetry-api==1.22.0
# opentelemetry-exporter-otlp==1.22.0
# opentelemetry-exporter-otlp-proto-common==1.22.0
# opentelemetry-exporter-otlp-proto-grpc==1.22.0
# opentelemetry-exporter-otlp-proto-http==1.22.0
# opentelemetry-proto==1.22.0
# opentelemetry-sdk==1.22.0
# opentelemetry-semantic-conventions==0.43b0
# opt-einsum==3.3.0
# optax==0.1.9
# optuna==3.5.0
# orbax-checkpoint==0.5.3
# ordered-set==4.1.0
# orderedmultidict==1.0.1
# orjson==3.9.10
# ortools==9.4.1874
# osmnx==1.9.1
# overrides @ file:///home/conda/feedstock_root/build_artifacts/overrides_1691338815398/work
# packaging==21.3
# pandas==2.1.4
# pandas-datareader==0.10.0
# pandas-profiling==3.6.6
# pandas-summary==0.2.0
# pandasql==0.7.3
# pandocfilters @ file:///home/conda/feedstock_root/build_artifacts/pandocfilters_1631603243851/work
# panel==1.3.8
# papermill==2.5.0
# param==2.0.2
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1638334955874/work
# partd @ file:///home/conda/feedstock_root/build_artifacts/partd_1695667515973/work
# path==16.10.0
# path.py==12.5.0
# pathos==0.3.2
# pathy @ file:///croot/pathy_1703688110387/work
# patsy==0.5.6
# pdf2image==1.17.0
# pettingzoo==1.24.0
# pexpect @ file:///home/conda/feedstock_root/build_artifacts/pexpect_1667297516076/work
# phik==0.12.4
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# Pillow==9.5.0
# pkgutil_resolve_name @ file:///home/conda/feedstock_root/build_artifacts/pkgutil-resolve-name_1694617248815/work
# platformdirs==4.2.0
# plotly==5.18.0
# plotly-express==0.4.1
# plotnine==0.13.0
# pluggy @ file:///home/conda/feedstock_root/build_artifacts/pluggy_1693086607691/work
# pointpats==2.4.0
# polars==0.20.10
# polyglot==16.7.4
# pooch==1.8.1
# pox==0.3.4
# ppca==0.0.4
# ppft==1.7.6.8
# preprocessing==0.1.13
# preshed @ file:///home/conda/feedstock_root/build_artifacts/preshed_1695644760607/work
# prettytable==3.9.0
# progressbar2==4.3.2
# prometheus-client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1700579315247/work
# promise==2.3
# prompt-toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1702399386289/work
# pronouncing==0.2.0
# prophet==1.1.1
# proto-plus @ file:///home/conda/feedstock_root/build_artifacts/proto-plus_1702003338643/work
# protobuf==3.20.3
# psutil==5.9.3
# ptyprocess @ file:///home/conda/feedstock_root/build_artifacts/ptyprocess_1609419310487/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# pudb==2024.1
# PuLP==2.8.0
# pure-eval @ file:///home/conda/feedstock_root/build_artifacts/pure_eval_1642875951954/work
# py-cpuinfo==9.0.0
# py-spy==0.3.14
# py4j==0.10.9.7
# pyaml==23.12.0
# PyArabic==0.6.15
# pyarrow==11.0.0
# pyasn1 @ file:///home/conda/feedstock_root/build_artifacts/pyasn1_1701287008248/work
# pyasn1-modules @ file:///home/conda/feedstock_root/build_artifacts/pyasn1-modules_1695107857548/work
# PyAstronomy==0.20.0
# pybind11==2.11.1
# pyclipper==1.3.0.post5
# pycodestyle==2.11.1
# pycosat @ file:///home/conda/feedstock_root/build_artifacts/pycosat_1696355758174/work
# pycparser @ file:///tmp/build/80754af9/pycparser_1636541352034/work
# pycryptodome==3.20.0
# pyct==0.5.0
# pycuda==2024.1
# pydantic==2.5.3
# pydantic_core==2.14.6
# pydegensac==0.1.2
# pydicom==2.4.4
# pydocstyle==6.3.0
# pydot==1.4.2
# pydub==0.25.1
# pyemd==1.0.0
# pyerfa==2.0.1.1
# pyexcel-io==0.6.6
# pyexcel-ods==0.6.0
# pyfasttext==0.4.6
# pyflakes==3.2.0
# pygltflib==1.16.1
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1700607939962/work
# PyJWT==2.8.0
# pykalman==0.9.5
# pyLDAvis==3.4.1
# pylibraft @ file:///opt/conda/conda-bld/work/python/pylibraft
# pylint==3.0.3
# pymc3==3.11.4
# PyMeeus==0.5.12
# pymongo==3.13.0
# Pympler==1.0.1
# pynndescent==0.5.11
# pynvml @ file:///home/conda/feedstock_root/build_artifacts/pynvml_1639061605391/work
# pynvrtc==9.2
# pyocr==0.8.5
# pyOpenSSL @ file:///home/conda/feedstock_root/build_artifacts/pyopenssl_1698795453264/work
# pyparsing @ file:///home/conda/feedstock_root/build_artifacts/pyparsing_1690737849915/work
# pypdf==4.0.2
# pyproj @ file:///home/conda/feedstock_root/build_artifacts/pyproj_1702028071709/work
# pysal==24.1
# pyshp @ file:///home/conda/feedstock_root/build_artifacts/pyshp_1659002966020/work
# PySocks @ file:///home/builder/ci_310/pysocks_1640793678128/work
# pytesseract==0.3.10
# pytest==8.0.1
# python-bidi==0.4.2
# python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1626286286081/work
# python-dotenv==1.0.0
# python-json-logger @ file:///home/conda/feedstock_root/build_artifacts/python-json-logger_1677079630776/work
# python-Levenshtein==0.25.0
# python-louvain==0.16
# python-lsp-jsonrpc==1.1.2
# python-lsp-server==1.10.0
# python-slugify==8.0.4
# python-utils==3.8.2
# pythreejs==2.4.2
# pytoolconfig==1.3.1
# pytools==2023.1.1
# pytorch-ignite==0.4.13
# pytorch-lightning==2.2.0.post0
# pytz==2023.3.post1
# pyu2f @ file:///home/conda/feedstock_root/build_artifacts/pyu2f_1604248910016/work
# PyUpSet==0.1.1.post7
# pyviz_comms==3.0.1
# PyWavelets==1.5.0
# PyYAML @ file:///home/conda/feedstock_root/build_artifacts/pyyaml_1695373428874/work
# pyzmq==24.0.1
# qgrid==1.3.1
# qtconsole==5.5.1
# QtPy==2.4.1
# quantecon==0.7.1
# quantities==0.15.0
# qudida==0.0.4
# raft-dask @ file:///opt/conda/conda-bld/work/python/raft-dask
# rapidfuzz==3.6.1
# rasterio==1.3.9
# rasterstats==0.19.0
# ray==2.9.0
# ray-cpp==2.9.0
# referencing @ file:///home/conda/feedstock_root/build_artifacts/referencing_1704489226496/work
# regex==2023.12.25
# requests @ file:///home/conda/feedstock_root/build_artifacts/requests_1684774241324/work
# requests-oauthlib==1.3.1
# requests-toolbelt==0.10.1
# responses==0.18.0
# retrying==1.3.3
# rfc3339-validator @ file:///home/conda/feedstock_root/build_artifacts/rfc3339-validator_1638811747357/work
# rfc3986-validator @ file:///home/conda/feedstock_root/build_artifacts/rfc3986-validator_1598024191506/work
# rgf-python==3.12.0
# rich @ file:///home/conda/feedstock_root/build_artifacts/rich-split_1700160075651/work/dist
# rich-click==1.7.3
# rmm @ file:///opt/conda/conda-bld/work/python
# rope==1.12.0
# rpds-py @ file:///home/conda/feedstock_root/build_artifacts/rpds-py_1703822618592/work
# rsa @ file:///home/conda/feedstock_root/build_artifacts/rsa_1658328885051/work
# Rtree==1.2.0
# ruamel-yaml-conda @ file:///home/builder/ci_310/ruamel_yaml_1640794439226/work
# ruamel.yaml @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml_1698138615000/work
# ruamel.yaml.clib @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml.clib_1695996839082/work
# s2sphere==0.2.5
# s3fs==2024.2.0
# s3transfer==0.6.2
# safetensors==0.4.2
# scattertext==0.1.19
# scikit-image==0.22.0
# scikit-learn==1.2.2
# scikit-learn-intelex==2024.1.0
# scikit-multilearn==0.2.0
# scikit-optimize==0.9.0
# scikit-plot==0.3.7
# scikit-surprise==1.1.3
# scipy==1.11.4
# seaborn==0.12.2
# SecretStorage==3.3.3
# segment_anything @ git+https://github.com/facebookresearch/segment-anything.git@6fdee8f2727f4506cfbbe553e23b895e27956588
# segregation==2.5
# semver==3.0.2
# Send2Trash @ file:///home/conda/feedstock_root/build_artifacts/send2trash_1682601222253/work
# sentencepiece==0.2.0
# sentry-sdk==1.40.5
# setproctitle==1.3.3
# setuptools-git==1.2
# setuptools-scm==8.0.4
# shap==0.44.1
# Shapely==1.8.5.post1
# shellingham @ file:///home/conda/feedstock_root/build_artifacts/shellingham_1698144360966/work
# Shimmy==1.3.0
# simpervisor==1.0.0
# SimpleITK==2.3.1
# simplejson==3.19.2
# six @ file:///tmp/build/80754af9/six_1644875935023/work
# sklearn-pandas==2.2.0
# slicer==0.0.7
# smart-open @ file:///home/conda/feedstock_root/build_artifacts/smart_open_split_1694066705667/work/dist
# smhasher==0.150.1
# smmap==5.0.1
# sniffio @ file:///home/conda/feedstock_root/build_artifacts/sniffio_1662051266223/work
# snowballstemmer==2.2.0
# snuggs==1.4.7
# sortedcontainers @ file:///home/conda/feedstock_root/build_artifacts/sortedcontainers_1621217038088/work
# soundfile==0.12.1
# soupsieve @ file:///home/conda/feedstock_root/build_artifacts/soupsieve_1693929250441/work
# soxr==0.3.7
# spacy @ file:///home/conda/feedstock_root/build_artifacts/spacy_1699194962107/work
# spacy-legacy @ file:///home/conda/feedstock_root/build_artifacts/spacy-legacy_1674550301837/work
# spacy-loggers @ file:///home/conda/feedstock_root/build_artifacts/spacy-loggers_1694527114282/work
# spaghetti==1.7.5.post1
# spectral==0.23.1
# spglm==1.1.0
# sphinx-rtd-theme==0.2.4
# spint==1.0.7
# splot==1.1.5.post1
# spopt==0.6.0
# spreg==1.4.2
# spvcm==0.3.0
# SQLAlchemy==2.0.25
# sqlparse==0.4.4
# squarify==0.4.3
# srsly @ file:///home/conda/feedstock_root/build_artifacts/srsly_1695653949688/work
# stable-baselines3==2.1.0
# stack-data @ file:///home/conda/feedstock_root/build_artifacts/stack_data_1669632077133/work
# stanio==0.3.0
# starlette==0.32.0.post1
# statsmodels==0.14.1
# stemming==1.0.1
# stop-words==2018.7.23
# stopit==1.1.2
# stumpy==1.12.0
# sympy==1.12
# tables==3.9.2
# tabulate==0.9.0
# tangled-up-in-unicode==0.2.0
# tbb==2021.11.0
# tblib @ file:///home/conda/feedstock_root/build_artifacts/tblib_1702066284995/work
# tenacity==8.2.3
# tensorboard==2.15.1
# tensorboard-data-server==0.7.2
# tensorboard-plugin-profile==2.15.0
# tensorboardX==2.6.2.2
# tensorflow==2.15.0
# tensorflow-cloud==0.1.16
# tensorflow-datasets==4.9.4
# tensorflow-decision-forests==1.8.1
# tensorflow-estimator==2.15.0
# tensorflow-hub==0.16.1
# tensorflow-io==0.35.0
# tensorflow-io-gcs-filesystem==0.35.0
# tensorflow-metadata==0.14.0
# tensorflow-probability==0.23.0
# tensorflow-serving-api==2.14.1
# tensorflow-text==2.15.0
# tensorflow-transform==0.14.0
# tensorpack==0.11
# tensorstore==0.1.53
# termcolor==2.4.0
# terminado @ file:///home/conda/feedstock_root/build_artifacts/terminado_1699810101464/work
# testpath==0.6.0
# text-unidecode==1.3
# textblob==0.18.0.post0
# texttable==1.7.0
# tf-keras==2.15.0
# tfp-nightly @ git+https://github.com/tensorflow/probability.git@fbc5ebe9b1d343113fb917010096cfd88b32eecf
# Theano==1.0.5
# Theano-PyMC==1.1.2
# thinc @ file:///home/conda/feedstock_root/build_artifacts/thinc_1703842165913/work
# threadpoolctl==3.2.0
# tifffile==2023.12.9
# timm==0.9.16
# tinycss2 @ file:///home/conda/feedstock_root/build_artifacts/tinycss2_1666100256010/work
# tobler==0.11.2
# tokenizers==0.15.2
# toml==0.10.2
# tomli==2.0.1
# tomlkit==0.12.3
# toolz @ file:///home/conda/feedstock_root/build_artifacts/toolz_1706112571092/work
# torch @ file:///tmp/torch/torch-2.1.2-cp310-cp310-linux_x86_64.whl#sha256=ae3259980b8d6551608b32fde2695baca64c72ed15ab2332023a248c113815a8
# torchaudio @ file:///tmp/torch/torchaudio-2.1.2-cp310-cp310-linux_x86_64.whl#sha256=10966b20361b49bc41b6c6ba842d3ea842320fb8c589823b4120f24a98013b4a
# torchdata==0.7.1
# torchinfo==1.8.0
# torchmetrics==1.3.1
# torchtext @ file:///tmp/torch/torchtext-0.16.2-cp310-cp310-linux_x86_64.whl#sha256=a2a382655a08e1f6eeab6a307d0c8d78139cfa04cc329a7dc15a3f7c1e6e7a19
# torchvision @ file:///tmp/torch/torchvision-0.16.2-cp310-cp310-linux_x86_64.whl#sha256=105901a20924f652ee62df0bb57580c67725eb21f11a349658952c4be2050d94
# tornado @ file:///home/conda/feedstock_root/build_artifacts/tornado_1695373560918/work
# TPOT==0.12.1
# tqdm @ file:///home/conda/feedstock_root/build_artifacts/tqdm_1691671248568/work
# traceml==1.0.8
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1675110562325/work
# traittypes==0.2.1
# transformers==4.38.1
# treelite==3.2.0
# treelite-runtime==3.2.0
# trueskill==0.4.5
# truststore @ file:///home/conda/feedstock_root/build_artifacts/truststore_1694154605758/work
# trx-python==0.2.9
# tsfresh==0.20.2
# typeguard==4.1.5
# typer @ file:///home/conda/feedstock_root/build_artifacts/typer_1683029246636/work
# types-python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/types-python-dateutil_1704512562698/work
# typing-inspect==0.9.0
# typing-utils @ file:///home/conda/feedstock_root/build_artifacts/typing_utils_1622899189314/work
# typing_extensions @ file:///home/conda/feedstock_root/build_artifacts/typing_extensions_1702176139754/work
# tzdata==2023.4
# tzlocal==5.2
# uc-micro-py==1.0.3
# ucx-py @ file:///opt/conda/conda-bld/work
# ujson==5.9.0
# umap-learn==0.5.5
# unicodedata2 @ file:///home/conda/feedstock_root/build_artifacts/unicodedata2_1695847980273/work
# Unidecode==1.3.8
# update-checker==0.18.0
# uri-template @ file:///home/conda/feedstock_root/build_artifacts/uri-template_1688655812972/work/dist
# uritemplate==3.0.1
# urllib3==1.26.18
# urwid==2.6.4
# urwid_readline==0.13
# uvicorn==0.25.0
# uvloop==0.19.0
# vaex==4.17.0
# vaex-astro==0.9.3
# vaex-core==4.17.1
# vaex-hdf5==0.14.1
# vaex-jupyter==0.8.2
# vaex-ml==0.18.3
# vaex-server==0.9.0
# vaex-viz==0.5.4
# vec_noise==1.1.4
# vecstack==0.4.0
# virtualenv==20.21.0
# visions==0.7.5
# vowpalwabbit==9.9.0
# vtk==9.3.0
# Wand==0.6.13
# wandb==0.16.3
# wasabi @ file:///home/conda/feedstock_root/build_artifacts/wasabi_1686131297168/work
# watchfiles==0.21.0
# wavio==0.0.8
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1704731205417/work
# weasel @ file:///home/conda/feedstock_root/build_artifacts/weasel_1699295455892/work
# webcolors @ file:///home/conda/feedstock_root/build_artifacts/webcolors_1679900785843/work
# webencodings @ file:///home/conda/feedstock_root/build_artifacts/webencodings_1694681268211/work
# websocket-client @ file:///home/conda/feedstock_root/build_artifacts/websocket-client_1701630677416/work
# websockets==12.0
# Werkzeug==3.0.1
# wfdb==4.1.2
# whatthepatch==1.0.5
# widgetsnbextension==3.6.6
# witwidget==1.8.1
# woodwork==0.28.0
# wordcloud==1.9.3
# wordsegment==1.3.1
# wrapt==1.14.1
# xarray==2024.2.0
# xarray-einstats==0.7.0
# xgboost==2.0.3
# xvfbwrapper==0.2.9
# xxhash==3.4.1
# xyzservices @ file:///home/conda/feedstock_root/build_artifacts/xyzservices_1698325309404/work
# y-py==0.6.2
# yapf==0.40.2
# yarl @ file:///home/conda/feedstock_root/build_artifacts/yarl_1701168553642/work
# ydata-profiling==4.6.4
# yellowbrick==1.5
# ypy-websocket==0.8.4
# zict @ file:///home/conda/feedstock_root/build_artifacts/zict_1681770155528/work
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1695255097490/work
# zstandard==0.22.0

# %%
# All enviroment varaiables

print(os.environ)
# Out:
# environ({'SHELL': '/bin/bash', 'NV_LIBCUBLAS_VERSION': '12.1.0.26-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'TENSORFLOW_IO_VERSION': '0.35.0', 'NV_NVML_DEV_VERSION': '12.1.55-1', 'NV_CUDNN_PACKAGE_NAME': 'libcudnn8', 'NV_LIBNCCL_DEV_PACKAGE': 'libnccl-dev=2.17.1-1+cuda12.1', 'KMP_WARNINGS': '0', 'NV_LIBNCCL_DEV_PACKAGE_VERSION': '2.17.1-1', 'CUDA_MINOR_VERSION': '1', 'HOSTNAME': '7484790c3ed0', 'DL_ANACONDA_HOME': '/opt/conda', 'NODE_OPTIONS': '--max-old-space-size=4096', 'KAGGLE_DATA_PROXY_TOKEN': 'eyJhbGciOiJBMTI4S1ciLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0.tTeq0F5JWMbaaPmzrdvab5jO6P5Q3NplRYm-cDyHPeLW5Ctj-2W45g.56uMdKq3dcvhM2kdMrIxZQ.bJy1-fyB_QsK8l4U_Z3ZdKHwb67v8n-B4kZ9je1nbg3Oz4IO68HFQW-QpnrCgd_gTee5hd7V8YZZVmlua3cKRR9Lsz4EzZk8mWckDuXSNc-wQL3PFtsAyy5QGaEYxRuYUxJyQPueR-wzIbECYMAW6j5B646YCkwD8gIdMxD3vtETE6aZS_n7icn2cXpYcuNkXzDugBMSSbcNzHNDF4_nvD_p2-571DWNop4-4CE75YiFswY1Or1WEGAFAoxTbAhVJLKvZDCf84O8h7jQTgbQhEJH9OegO4H0V-Q0vb9yT8FC3P60-ddpYh92VLEx0v0q.-VDPekkbNaRM8ZHx5L7bJA', 'NVIDIA_REQUIRE_CUDA': 'cuda>=12.1 brand=tesla,driver>=470,driver<471 brand=unknown,driver>=470,driver<471 brand=nvidia,driver>=470,driver<471 brand=nvidiartx,driver>=470,driver<471 brand=geforce,driver>=470,driver<471 brand=geforcertx,driver>=470,driver<471 brand=quadro,driver>=470,driver<471 brand=quadrortx,driver>=470,driver<471 brand=titan,driver>=470,driver<471 brand=titanrtx,driver>=470,driver<471 brand=tesla,driver>=525,driver<526 brand=unknown,driver>=525,driver<526 brand=nvidia,driver>=525,driver<526 brand=nvidiartx,driver>=525,driver<526 brand=geforce,driver>=525,driver<526 brand=geforcertx,driver>=525,driver<526 brand=quadro,driver>=525,driver<526 brand=quadrortx,driver>=525,driver<526 brand=titan,driver>=525,driver<526 brand=titanrtx,driver>=525,driver<526', 'NV_LIBCUBLAS_DEV_PACKAGE': 'libcublas-dev-12-1=12.1.0.26-1', 'NV_NVTX_VERSION': '12.1.66-1', 'TF_CPP_MIN_LOG_LEVEL': '2', 'NV_CUDA_CUDART_DEV_VERSION': '12.1.55-1', 'NV_LIBCUSPARSE_VERSION': '12.0.2.55-1', 'KAGGLE_URL_BASE': 'https://www.kaggle.com', 'NV_LIBNPP_VERSION': '12.0.2.50-1', 'NCCL_VERSION': '2.17.1-1', 'KAGGLE_DOCKER_IMAGE': 'gcr.io/kaggle-gpu-images/python@sha256:e23c22630b6d9c427cbe8c1aa205f5e70a0f46c9aa0d3c835c6f0469306fa1aa', 'KAGGLE_KERNEL_INTEGRATIONS': '', 'CONTAINER_NAME': 'tf2-gpu/2-15+cu121', 'PWD': '/kaggle/working', 'TESSERACT_PATH': '/usr/bin/tesseract', 'TENSORFLOW_VERSION': '2.15.0', 'NV_CUDNN_PACKAGE': 'libcudnn8=8.9.0.131-1+cuda12.1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NV_NVPROF_DEV_PACKAGE': 'cuda-nvprof-12-1=12.1.55-1', 'NV_LIBNPP_PACKAGE': 'libnpp-12-1=12.0.2.50-1', 'BUILD_DATE': '20240222-122512', 'NV_LIBNCCL_DEV_PACKAGE_NAME': 'libnccl-dev', 'NV_LIBCUBLAS_DEV_VERSION': '12.1.0.26-1', 'NVIDIA_PRODUCT_NAME': 'CUDA', 'NV_LIBCUBLAS_DEV_PACKAGE_NAME': 'libcublas-dev-12-1', 'NV_CUDA_CUDART_VERSION': '12.1.55-1', 'HOME': '/root', 'LANG': 'C.UTF-8', 'NVIDIA_CUDA_END_OF_LIFE': '1', 'CUDA_VERSION': '12.1.0', 'NV_LIBCUBLAS_PACKAGE': 'libcublas-12-1=12.1.0.26-1', 'KMP_SETTINGS': 'false', 'NV_CUDA_NSIGHT_COMPUTE_DEV_PACKAGE': 'cuda-nsight-compute-12-1=12.1.0-1', 'NV_LIBNPP_DEV_PACKAGE': 'libnpp-dev-12-1=12.0.2.50-1', 'NV_LIBCUBLAS_PACKAGE_NAME': 'libcublas-12-1', 'NV_LIBNPP_DEV_VERSION': '12.0.2.50-1', 'LD_LIBRARY_PATH_NO_STUBS': '/usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib', 'ANACONDA_PYTHON_VERSION': '3.10', 'PYTHONPATH': '/kaggle/lib/kagglegym:/kaggle/lib', 'NV_LIBCUSPARSE_DEV_VERSION': '12.0.2.55-1', 'KAGGLE_DATA_PROXY_PROJECT': 'kaggle-161607', 'GCSFUSE_METADATA_IMAGE_TYPE': 'DLC', 'KAGGLE_USER_SECRETS_TOKEN': 'eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..v-6bsdpShQIQP8HedKtAhA.m0Ipsi0sAy92otMw65B8tXiJ0Zlex6---fBO4ZzZ-7NHQFDp45S6Aq6zJGv4fLMfuObq4qH5SGyVMfRsEEA5Gba6EzHcO2AEXICHMizxQ06jy1vqQwXzMKLJAuDlMbZfSUYxCujj2QXZA7S5tYv3qA.R7XvsVJeZTYDboDcoRXboA', 'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs:/opt/conda/lib', 'NV_CUDNN_VERS ...

# %% [markdown]
# # Delete all files in working directory

# %%
working_directory = '/kaggle/working'

for file in os.listdir(working_directory):
    file_path = os.path.join(working_directory, file)

    if os.path.isfile(file_path):
        os.remove(file_path)

print("All files in the working directory deleted.")
# Out:
# All files in the working directory deleted.
